# %% [markdown]
# # End to End Medial Diagnostic Use Case

# %% [markdown]
# Steps of the project:
# 0. Create a virtual environment with python=3.8.13
# 1. Import and view the data
# 2. Check the data for Sanity
# 3. Perform EDA on data set
# 4. Preprocess the data for modelling
# 5. Fit and Evlaute various Models
# 6. Optimize the chosen model
# 7. Interpret the optimized model
# 8. Pickle and save the model as a pipeline
# 9. Deploy the model pipeline in streamlit
# 10. Scale model to cloud using git and streamlit sharing

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in d:\aparajitkr14\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in d:\aparajitkr14\lib\site-packages (from imbalanced-learn) (1.21.5)
# Requirement already satisfied: scikit-learn>=1.0.2 in d:\aparajitkr14\lib\site-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\aparajitkr14\lib\site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in d:\aparajitkr14\lib\site-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: joblib>=1.1.1 in d:\aparajitkr14\lib\site-packages (from imbalanced-learn) (1.2.0)

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.7.4-py3-none-win_amd64.whl (89.1 MB)
# Requirement already satisfied: scipy in d:\aparajitkr14\lib\site-packages (from xgboost) (1.7.3)
# Requirement already satisfied: numpy in d:\aparajitkr14\lib\site-packages (from xgboost) (1.21.5)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.7.4

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.41.0-cp39-cp39-win_amd64.whl (435 kB)
# Requirement already satisfied: scikit-learn in d:\aparajitkr14\lib\site-packages (from shap) (1.0.2)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy in d:\aparajitkr14\lib\site-packages (from shap) (1.21.5)
# Requirement already satisfied: packaging>20.9 in d:\aparajitkr14\lib\site-packages (from shap) (21.3)
# Requirement already satisfied: tqdm>4.25.0 in d:\aparajitkr14\lib\site-packages (from shap) (4.64.0)
# Requirement already satisfied: scipy in d:\aparajitkr14\lib\site-packages (from shap) (1.7.3)
# Requirement already satisfied: cloudpickle in d:\aparajitkr14\lib\site-packages (from shap) (2.0.0)
# Requirement already satisfied: pandas in d:\aparajitkr14\lib\site-packages (from shap) (1.4.2)
# Requirement already satisfied: numba in d:\aparajitkr14\lib\site-packages (from shap) (0.55.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\aparajitkr14\lib\site-packages (from packaging>20.9->shap) (3.0.4)
# Requirement already satisfied: colorama in d:\aparajitkr14\lib\site-packages (from tqdm>4.25.0->shap) (0.4.4)
# Requirement already satisfied: setuptools in d:\aparajitkr14\lib\site-packages (from numba->shap) (61.2.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in d:\aparajitkr14\lib\site-packages (from numba->shap) (0.38.0)
# Requirement already satisfied: pytz>=2020.1 in d:\aparajitkr14\lib\site-packages (from pandas->shap) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\aparajitkr14\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\aparajitkr14\lib\site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in d:\aparajitkr14\lib\site-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\aparajitkr14\lib\site-packages (from scikit-learn->shap) (2.2.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7

# %%
# Load all the librarires
# for data manipulation and visualization 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')
plt.style.use('fivethirtyeight')

# preprocessing modules
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from imblearn.over_sampling import SMOTE

# modelling modules
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier,GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC

# modules for model evaluation
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score, f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import plot_precision_recall_curve

#for model interpretation
import shap

# deployment module
#import streamlit as st

print("All Libraries are imported")
# Out:
# All Libraries are imported

# %% [markdown]
# ### 1. Import and view the data

# %%
data=pd.read_csv('data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0           0            6      148             72             35        0
# 1           1            1       85             66             29        0
# 2           2            8      183             64              0        0
# 3           3            1       89             66             23       94
# 4           4            0      137             40             35      168
#
#     BMI  DiabetesPedigreeFunction  Age Outcome
# 0  33.6                     0.627   50     Yes
# 1  26.6                     0.351   31      No
# 2  23.3                     0.672   32     Yes
# 3  28.1                     0.167   21      No
# 4  43.1                     2.288   33     Yes

# %%
data.shape
# Out:
# (768, 10)

# %% [markdown]
# ###  Check the data for Sanity

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                768 non-null    int64
#  1   Pregnancies               768 non-null    int64
#  2   Glucose                   768 non-null    int64
#  3   BloodPressure             768 non-null    int64
#  4   SkinThickness             768 non-null    int64
#  5   Insulin                   768 non-null    int64
#  6   BMI                       768 non-null    float64
#  7   DiabetesPedigreeFunction  768 non-null    float64
#  8   Age                       768 non-null    int64
#  9   Outcome                   768 non-null    object
# dtypes: float64(2), int64(7), object(1)
# memory usage: 60.1+ KB

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                  0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.describe().T
# Out:
#                           count        mean         std     min        25%  \
# Unnamed: 0                768.0  383.500000  221.846794   0.000  191.75000
# Pregnancies               768.0    3.845052    3.369578   0.000    1.00000
# Glucose                   768.0  120.894531   31.972618   0.000   99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000   62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000    0.00000
# Insulin                   768.0   79.799479  115.244002   0.000    0.00000
# BMI                       768.0   31.992578    7.884160   0.000   27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078    0.24375
# Age                       768.0   33.240885   11.760232  21.000   24.00000
#
#                                50%        75%     max
# Unnamed: 0                383.5000  575.25000  767.00
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00

# %%
# check for any other non real characters
data[~data.applymap(np.isreal).any(1)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %% [markdown]
# **Observations**
# 1. Data set has 768 rows and 10 columns( 1 redundant)
# 2. Dataset has no direct nulls but has nulls imputed as 0
# 3. Dataset has only 1 categorical variable the Outcome

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Pregnancies', 'Glucose', 'BloodPressure',
#        'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age',
#        'Outcome'],
#       dtype='object')

# %%
# drop the redundant column
data=data.drop('Unnamed: 0', axis=1)

# %%
# treat the nulls
zerofiller=lambda x: x.replace(0, x.median())
cols=data.columns[1:6]
data[cols]=data[cols].apply(zerofiller, axis=0)

# %%
#encode categoricals
df=data.copy()
d={'Yes':1, 'No':0}
df['Outcome']=df['Outcome'].map(d)

# %%
df.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35     30.5  33.6
# 1            1       85             66             29     30.5  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %% [markdown]
# ### Perform EDA on data set
# 1. UNIVARIATES- NUMERICALS
# 2. UNIVARIATES-CATEGORICALS
# 3. BIVARIATES-NUMERICAL vs CATEGORICAL
# 4. BIVARIATES- NUMERICALS VS NUMERICLAS
# 5. MULTIVARIATE CHARTS
# 6. Correlations and Heatmaps

# %% [markdown]
# ##### 1. UNIVARIATES

# %%
def histograms(data):
    print('Univariate Histogram')
    data.hist()
    plt.tight_layout()
    plt.show()

# %%
histograms(df)
# Out:
# Univariate Histogram

# %%
def barchart(data, feature):
    print("Barchart of Categoricals")
    ax=sns.countplot(data=data, x=feature, color='green')
    for p in ax.patches:
        x=p.get_bbox().get_points()[:,0]
        y=p.get_bbox().get_points()[1,1]
        ax.annotate("{:.2g}%".format(100.*y/len(data)), (x.mean(),y), ha='center' , va='bottom')                                  
    plt.show()

# %%
barchart(data=df, feature='Outcome')
# Out:
# Barchart of Categoricals

# %% [markdown]
# **Observations**
# Outcome variable is highly imbalanced. We need to solve for data imbalance

# %%
def boxpolot_histplot(data, feature, figsize=(12,7), bins=None):
    print("Univariates of ", feature)
    fig, (ax_box, ax_hist)=plt.subplots(
    nrows=2,
    sharex=True,
    gridspec_kw={'height_ratios':(0.25,0.75)},
    figsize=figsize)
    
    sns.boxplot(data=data,x=feature, showmeans=True, ax=ax_box, color='violet')
    
    sns.histplot(data=data, x=feature, bins=bins, ax=ax_hist, pallete='winter') if bins else\
         sns.histplot(data=data,x=feature, ax=ax_hist)
    plt.axvline(data[feature].mean(),linestyle='--', color='green')
    plt.axvline(data[feature].median(), linestyle='-', color='black')
    plt.show()

# %%
for col in df.select_dtypes(exclude='O').columns:
    boxpolot_histplot(data=df, feature=col)
# Out:
# Univariates of  Pregnancies
# Univariates of  Glucose
# Univariates of  BloodPressure
# Univariates of  SkinThickness
# Univariates of  Insulin
# Univariates of  BMI
# Univariates of  DiabetesPedigreeFunction
# Univariates of  Age
# Univariates of  Outcome

# %% [markdown]
# **Observations**
# 1. Pregnancies has some suspect outliers which have to be looked upon
# 2. Skin thickness also has some suspect outliers which need to be taken care of
# 3. Insulin is highly right skewed aand may need to be engineered
# 4. Diabetes pedigree function is also highly right skewed and needs to be engineered.
# 5. Outcome is highly imbalanced and may need balancing.

# %% [markdown]
# ##### BIVARIATES-NUMERICAL vs CATEGORICAL

# %%
def catnums(data, feature1, feature2):
    print("Bivariate Barchart between {0} and {1}".format(feature1, feature2))
    data.groupby(feature1)[feature2].mean().plot(kind='bar',color='orange')
    plt.show()

# %%
for col in data.select_dtypes(exclude='O').columns:
    catnums(data=data, feature1='Outcome', feature2=col)
# Out:
# Bivariate Barchart between Outcome and Pregnancies
# Bivariate Barchart between Outcome and Glucose
# Bivariate Barchart between Outcome and BloodPressure
# Bivariate Barchart between Outcome and SkinThickness
# Bivariate Barchart between Outcome and Insulin
# Bivariate Barchart between Outcome and BMI
# Bivariate Barchart between Outcome and DiabetesPedigreeFunction
# Bivariate Barchart between Outcome and Age

# %% [markdown]
# **Observations**
# Woman with higher pregnancies, higher diabetes predigree functions and Insulin use are more likely to be diabetic

# %% [markdown]
# ##### BIVARIATES-NUMERICAL vs NUMERICAL

# %%
def lineplot_scatterplot(data, feature1, feature2):
    print("Bivariates between {0} and {1}".format(feature1, feature2))
    plt.figure(figsize=(16,7))
    plt.subplot(1,2,1)
    sns.lineplot(data=data, x=feature1, y=feature2, color='green')
    plt.subplot(1,2,2)
    sns.scatterplot(data=data, x=feature1, y=feature2, color='blue')
    plt.show()

# %%
for col in data.select_dtypes(exclude='O').columns:
    lineplot_scatterplot(data=data, feature1='Pregnancies', feature2=col)
# Out:
# Bivariates between Pregnancies and Pregnancies
# Bivariates between Pregnancies and Glucose
# Bivariates between Pregnancies and BloodPressure
# Bivariates between Pregnancies and SkinThickness
# Bivariates between Pregnancies and Insulin
# Bivariates between Pregnancies and BMI
# Bivariates between Pregnancies and DiabetesPedigreeFunction
# Bivariates between Pregnancies and Age

# %% [markdown]
# ##### MULTIVARIATE CHARTS

# %%
sns.pairplot(data=df, hue='Outcome', kind='reg')

# %% [markdown]
# ##### Correlations and Heatmaps

# %%
df[df.columns[:]].corr()['Outcome']
# Out:
# Pregnancies                 0.221898
# Glucose                     0.492782
# BloodPressure               0.165723
# SkinThickness               0.189065
# Insulin                     0.148457
# BMI                         0.312249
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(), annot=True, cmap='Spectral', vmax=+1, vmin=-1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Observations**
# Glucose and BMI seem to be strongest predictors of Diabetes

# %%
# %%writefile eda.py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import streamlit as st
st.set_option('deprecation.showPyplotGlobalUse', False)
st.title("The EDA Page")

def main():
    st.sidebar.subheader("Please choose the plot")
    data=pd.read_csv('data.csv')
    # drop the redundant column
    data=data.drop('Unnamed: 0', axis=1)
    # treat the nulls
    zerofiller=lambda x: x.replace(0, x.median())
    cols=data.columns[1:6]
    data[cols]=data[cols].apply(zerofiller, axis=0)
    #encode categoricals
    df=data.copy()
    d={'Yes':1, 'No':0}
    df['Outcome']=df['Outcome'].map(d)
    
    def histograms(data):
        st.subheader('Univariate Histogram')
        data.hist()
        plt.tight_layout()
        st.pyplot()
    def barchart(data, feature):
        st.subheader("Barchart of Categoricals")
        ax=sns.countplot(data=data, x=feature, color='green')
        for p in ax.patches:
            x=p.get_bbox().get_points()[:,0]
            y=p.get_bbox().get_points()[1,1]
            ax.annotate("{:.2g}%".format(100.*y/len(data)), (x.mean(),y), ha='center' , va='bottom')                                  
        st.pyplot()
        
    def heatmap(data):
        st.subheader("The Heatmap")
        plt.figure(figsize=(12,7))
        sns.heatmap(df.corr(), annot=True, cmap='Spectral', vmax=+1, vmin=-1)
        st.pyplot()
        
    plot=st.sidebar.selectbox('Choose Plot',('Histograms', 'Barchart', 'Heatmap'))
    if st.sidebar.button("PLOT"):
        if plot=='Histograms':
            histograms(df)
        if plot=='Barchart':
            barchart(data=df, feature='Outcome')
        if plot=='Heatmap':
            heatmap(data=df)
        
if __name__=='__main__':
    main()
# Out:
# Overwriting eda.py

# %%
def preprocessing (df,label):
    x=df.drop(label,axis=1)
    y=df[label]
    from imblearn.over_sampling import SMOTE
    sm=SMOTE()
    x,y=sm.fit_resample(x,y)
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
    return x_train,x_test,y_train,y_test

# %%
x_train,x_test,y_train,y_test =preprocessing(df,'Outcome')

# %%
#scale the features
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (700, 8) (700,) (300, 8) (300,)

# %%
# function to print metrics
def print_metrics(y_test,y_pred,model):
    print('Metrics for the model',model)
    print(' ')
    print("Accuracy score is ",accuracy_score(y_test,y_pred))
    print(' ')
    print("recall score is ",recall_score(y_test,y_pred))
    print(' ')
    print('precision score is',precision_score(y_test,y_pred))
    print(' ')
    print('f1 score is', f1_score(y_test,y_pred))
    print(' ')
    print(' Roc score is ',roc_auc_score(y_test,y_pred))
    print(' ')
    print('Confusion matrix \n', confusion_matrix(y_test,y_pred))
    print(' ')
    print('Classification report \n',classification_report(y_test,y_pred))

# %%
def plot_metrics(clf,x_test,y_test,model):
    print('plots for model',model)
    plot_confusion_matrix(clf,x_test,y_test,display_labels=[0,1])
    print('')
    plot_roc_curve(clf,x_test,y_test)
    print('')
    plot_precision_recall_curve(clf,x_test,y_test)

# %%
plot_metrics()

# %%
#create and fit a KNN model

knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
print_metrics(y_test,y_pred,'KNN')
# Out:
# Metrics for the model KNN
#
# Accuracy score is  0.7733333333333333
#
# recall score is  0.8543046357615894
#
# precision score is 0.7371428571428571
#
# f1 score is 0.7914110429447853
#
#  Roc score is  0.7727899017734122
#
# Confusion matrix
#  [[103  46]
#  [ 22 129]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.82      0.69      0.75       149
#            1       0.74      0.85      0.79       151
#
#     accuracy                           0.77       300
#    macro avg       0.78      0.77      0.77       300
# weighted avg       0.78      0.77      0.77       300

# %%
#lets try to optimize the KNN using a model complexity curve

# %%
neighbors=np.arange(1,20)
train_accuracies=np.empty(len(neighbors))
test_accuracies=np.empty(len(neighbors))

#enumerate along the neighbors

for i,k in enumerate (neighbors):
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train,y_train)
    train_accuracies[i]=knn.score(x_train,y_train)
    test_accuracies[i]=knn.score(x_test,y_test)

#plot the model complexity curves
plt.title("Accuracies for various neighbors")
plt.plot(neighbors,train_accuracies,label='Train Accuracies')
plt.plot(neighbors,test_accuracies,label='Test Accuracies')
plt.legend()
plt.xlabel('No. of neighbors')
plt.ylabel('Accuracies')
plt.show()

# %%
# both should not intersect or be straight lines

# %%
#Lets select the best model based on f1_score and optimize it

# %%
clfs = {'KNN' : KNeighborsClassifier(), 'NaiveBayes':GaussianNB(), 'Logregs':LogisticRegression(), 'Decision Tree':DecisionTreeClassifier(), 'Random Forest':RandomForestClassifier(), 'Ada Boost':AdaBoostClassifier(), 'Gradient Boosting': GradientBoostingClassifier(), 'XG Boost': XGBClassifier(), 'SVM': SVC()}
models_report = pd.DataFrame(columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score'])
for clf, clf_name in list(zip(clfs.values(), clfs.keys())):
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_test)
    print(f'Fitting the Model - {clf_name}')
    t = {'Model':clf_name, 'Accuracy': accuracy_score(y_test, y_pred), 'Precision' : precision_score(y_test, y_pred), 'Recall' : recall_score(y_test, y_pred), 'F1 Score' : recall_score(y_test, y_pred)}
    models_report = models_report.append(t, ignore_index = True)
models_report=models_report.sort_values(by = 'F1 Score', ascending = False)
models_report
# Out:
# Fitting the Model - KNN
# Fitting the Model - NaiveBayes
# Fitting the Model - Logregs
# Fitting the Model - Decision Tree
# Fitting the Model - Random Forest
# Fitting the Model - Ada Boost
# Fitting the Model - Gradient Boosting
# Fitting the Model - XG Boost
# Fitting the Model - SVM
#                Model  Accuracy Precision    Recall  F1 Score
# 4      Random Forest  0.813333  0.784431   0.86755   0.86755
# 0                KNN  0.773333  0.737143  0.854305  0.854305
# 7           XG Boost      0.79  0.761905  0.847682  0.847682
# 8                SVM      0.78  0.754491  0.834437  0.834437
# 6  Gradient Boosting      0.76  0.748428  0.788079  0.788079
# 3      Decision Tree  0.743333  0.737179  0.761589  0.761589
# 5          Ada Boost      0.76  0.761589  0.761589  0.761589
# 2            Logregs  0.746667  0.769784  0.708609  0.708609
# 1         NaiveBayes  0.746667  0.790698  0.675497  0.675497

# %% [markdown]
# #### Random forest has performed the best. So lets optimize this model

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
print_metrics(y_test,y_pred,'RFC')
# Out:
# Metrics for the model RFC
#
# Accuracy score is  0.8
#
# recall score is  0.8543046357615894
#
# precision score is 0.7724550898203593
#
# f1 score is 0.8113207547169813
#
#  Roc score is  0.7996355393573048
#
# Confusion matrix
#  [[111  38]
#  [ 22 129]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.83      0.74      0.79       149
#            1       0.77      0.85      0.81       151
#
#     accuracy                           0.80       300
#    macro avg       0.80      0.80      0.80       300
# weighted avg       0.80      0.80      0.80       300

# %%
param_grid={
    'n_estimators':[100,150,200,250],
    'min_samples_leaf':range(1,10,1),
    'min_samples_split':range(2,20,2),
    'max_depth':[2,4,'auto'],
    'max_features':['sqrt','log2'],
    'criterion':['gini','entropy']
}

# %%
n_fold=5
gr = GridSearchCV(estimator = rfc,param_grid=param_grid,cv=5,n_jobs=1,verbose=3,return_train_score=False)
gr.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 3888 candidates, totalling 19440 fits
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.836 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.757 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.757 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.814 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.793 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.821 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.779 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.771 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.821 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.800 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.829 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.757 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.750 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.829 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.814 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.779 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.764 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.764 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.829 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.793 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.807 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.757 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.764 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.807 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.814 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.779 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.779 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.821 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.807 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.807 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.771 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.750 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.814 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.786 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators

# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=150;, score=0.757 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=150;, score=0.814 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=150;, score=0.800 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=200;, score=0.829 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=200;, score=0.764 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=200;, score=0.757 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=14, n_estimators=200;, score=0.821 total time=   0.4s
# ...
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=0.800 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=0.793 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=200;, score=0.814 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=250;, score=0.843 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=250;, score=0.779 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=250;, score=0.793 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=250;, score=0.807 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=250;, score=0.821 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.771 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.807 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=100;, score=0.836 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=150;, score=0.829 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=150;, score=0.771 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=150;, score=0.800 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=150;, score=0.814 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=150;, score=0.807 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.821 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.779 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.807 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.800 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=200;, score=0.807 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=250;, score=0.821 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=250;, score=0.771 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=250;, score=0.807 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=250;, score=0.800 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=250;, score=0.807 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=100;, score=0.821 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=100;, score=0.771 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=100;, score=0.800 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=100;, score=0.793 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=100;, score=0.821 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=150;, score=0.814 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=150;, score=0.771 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=150;, score=0.807 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=150;, score=0.793 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=150;, score=0.821 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=200;, score=0.821 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=200;, score=0.786 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=200;, score=0.800 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=200;, score=0.807 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=200;, score=0.807 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=250;, score=0.829 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=250;, score=0.779 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=250;, score=0.807 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=250;, score=0.807 total time=   0.6s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [70], in <cell line: 3>()
#       1 n_fold=5
#       2 gr = GridSearchCV(estimator = rfc,param_grid=param_grid,cv=5,n_jobs=1,verbose=3,return_train_score=False)
# ----> 3 gr.fit(x_train,y_train)
#
# File D:\AparajitKR14\lib\site-packages\sklearn\model_selection\_search.py:891, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     885     results = self._format_results(
#     886         all_candidate_params, n_splits, all_out, all_more_results
#     887     )
#     889     return results
# --> 891 self._run_search(evaluate_candidates)
#     893 # multimetric is determined here because in the case of a callable
#     894 # self.scoring the return type is only known after calling
#     895 first_test_score = all_out[0]["test_scores"]
#
# File D:\AparajitKR14\lib\site-packages\sklearn\model_selection\_search.py:1392, in GridSearchCV._run_search(self, evaluate_candidates)
#    1390 def _run_search(self, evaluate_candidates):
#    1391     """Search all candidates in param_grid"""
# -> 1392     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File D:\AparajitKR14\lib\site-packages\sklearn\model_selection\_search.py:838, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     830 if self.verbose > 0:
#     831     print(
#     832         "Fitting {0} folds for each of {1} candidates,"
#     833         " totalling {2} fits".format(
#     834             n_splits, n_candidates, n_candidates * n_splits
#     835         )
#     836     )
# --> 838 out = parallel(
#     839     delayed(_fit_and_score)(
#     840         clone(base_estimator),
#     841         X,
#     842         y,
#     843         train=train,
#     844         test=test,
#     845         parameters=parameters,
#     846         split_progress=(split_idx, n_splits),
#     847         candidate_progress=(cand_idx, n_candidates),
#     848         **fit_and_score_kwargs,
#     849     )
#     850     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     851         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852     )
#     853 )
#     855 if len(out) < 1:
#     856     raise ValueError(
#     857         "No fits were performed. "
#     858         "Was the CV iterator empty? "
#     859         "Were there no candidates?"
#     860     )
#
# File D:\AparajitKR14\lib\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File D:\AparajitKR14\lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File D:\AparajitKR14\lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File D:\AparajitKR14\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File D:\AparajitKR14\lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File D:\AparajitKR14\lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File D:\AparajitKR14\lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File D:\AparajitKR14\lib\site-packages\sklearn\utils\fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File D:\AparajitKR14\lib\site-packages\sklearn\model_selection\_validation.py:680, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678         estimator.fit(X_train, **fit_params)
#     679     else:
# --> 680         estimator.fit(X_train, y_train, **fit_params)
#     682 except Exception:
#     683     # Note fit time as time until error
#     684     fit_time = time.time() - start_time
#
# File D:\AparajitKR14\lib\site-packages\sklearn\ensemble\_forest.py:439, in BaseForest.fit(self, X, y, sample_weight)
#     434 if self.warm_start and len(self.estimators_) > 0:
#     435     # We draw from the random state to get the random state we
#     436     # would have got if we hadn't used a warm_start.
#     437     random_state.randint(MAX_INT, size=len(self.estimators_))
# --> 439 trees = [
#     440     self._make_estimator(append=False, random_state=random_state)
#     441     for i in range(n_more_estimators)
#     442 ]
#     444 # Parallel loop: we prefer the threading backend as the Cython code
#     445 # for fitting the trees is internally releasing the Python GIL
#     446 # making threading more efficient than multiprocessing in
#     447 # that case. However, for joblib 0.12+ we respect any
#     448 # parallel_backend contexts set at a higher level,
#     449 # since correctness does not rely on using threads.
#     450 trees = Parallel(
#     451     n_jobs=self.n_jobs,
#     452     verbose=self.verbose,
#    (...)
#     467     for i, t in enumerate(trees)
#     468 )
#
# File D:\AparajitKR14\lib\site-packages\sklearn\ensemble\_forest.py:440, in <listcomp>(.0)
#     434 if self.warm_start and len(self.estimators_) > 0:
#     435     # We draw from the random state to get the random state we
#     436     # would have got if we hadn't used a warm_start.
#     437     random_state.randint(MAX_INT, size=len(self.estimators_))
#     439 trees = [
# --> 440     self._make_estimator(append=False, random_state=random_state)
#     441     for i in range(n_more_estimators)
#     442 ]
#     444 # Parallel loop: we prefer the threading backend as the Cython code
#     445 # for fitting the trees is internally releasing the Python GIL
#     446 # making threading more efficient than multiprocessing in
#     447 # that case. However, for joblib 0.12+ we respect any
#     448 # parallel_backend contexts set at a higher level,
#     449 # since correctness does not rely on using threads.
#     450 trees = Parallel(
#     451     n_jobs=self.n_jobs,
#     452     verbose=self.verbose,
#    (...)
#     467     for i, t in enumerate(trees)
#     468 )
#
# File D:\AparajitKR14\lib\site-packages\sklearn\ensemble\_base.py:171, in BaseEnsemble._make_estimator(self, append, random_state)
#     168         estimator.set_params(criterion="absolute_error")
#     170 if random_state is not None:
# --> 171     _set_random_states(estimator, random_state)
#     173 if append:
#     174     self.estimators_.append(estimator)
#
# File D:\AparajitKR14\lib\site-packages\sklearn\ensemble\_base.py:76, in _set_random_states(estimator, random_state)
#      74 random_state = check_random_state(random_state)
#      75 to_set = {}
# ---> 76 for key in sorted(estimator.get_params(deep=True)):
#      77     if key == "random_state" or key.endswith("__random_state"):
#      78         to_set[key] = random_state.randint(np.iinfo(np.int32).max)
#
# KeyboardInterrupt:

# %%
gr.best_score_

# %%
gr.best_estimator_

# %%
rfc

# %% [markdown]
# ### Step7 Interpret the optimised model

# %%
rfc_tuned=RandomForestClassifier(max_depth=4,max_features='log2',min_samples_leaf=5,min_samples_split=4)
rfc_tuned.fit(x_train,y_train)
y_pred=rfc_tuned.predict(x_test)
print_metrics(y_test,y_pred,'Random Forest')
# Out:
# Metrics for the model Random Forest
#
# Accuracy score is  0.78
#
# recall score is  0.8410596026490066
#
# precision score is 0.7514792899408284
#
# f1 score is 0.79375
#
#  Roc score is  0.7795902040090671
#
# Confusion matrix
#  [[107  42]
#  [ 24 127]]
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.82      0.72      0.76       149
#            1       0.75      0.84      0.79       151
#
#     accuracy                           0.78       300
#    macro avg       0.78      0.78      0.78       300
# weighted avg       0.78      0.78      0.78       300

# %%
import shap
X=df.drop('Outcome',axis=1)
value=shap.TreeExplainer(rfc).shap_values(x_test)
shap.summary_plot(value,x_train,plot_type='bar',feature_names=X.columns)

# %% [markdown]
# ## glucose,age,bmi are best estimators of diabetes

# %% [markdown]
# ### Step 8: Pickle and save the model as a pipeline

# %% [markdown]
# transforming steps can be saved in pipeline object

# %%
from sklearn.pipeline import Pipeline
sc=StandardScaler()
rfc_tuned=rfc_tuned
steps=[('scaler',sc),('rfc_tuned',rfc_tuned)]
pipeline=Pipeline(steps)
x_train,x_test,y_train,y_test=preprocessing(df,label='Outcome')
pipeline.fit(x_train,y_train)
y_pred=pipeline.predict(x_test)
plot_metrics(pipeline,x_test,y_test,'Pipeline')
#print_metrics(y_test,y_pred,'Pipeline')
# Out:
# plots for model Pipeline

# %%
#save the pipeline as a pickle file

# %%
import pickle
model=open("rfc.pickle",'wb')
pickle.dump(pipeline,model)
model.close()

# %% [markdown]
# ## step9 deploy the model as a streamlit file

# %%
# %%writefile app.py
import streamlit as st
st.title('Medical Diagnostic web app')
st.subheader('Is the patient diabetic')
import pandas as pd
import pickle
from sklearn.preprocessing import StandardScaler

#Step1: Load the pickled model
model=open('rfc.pickle','rb')
clf=pickle.load(model)
model.close()

#Step2:Get the input from the front end user
pregs=st.number_input('Pregnancies',0,17,0)
glucose=st.slider('Glucose', 40,200,40)
bp=st.slider('BloodPressure', 20,140,20)
skin=st.slider('SkinThickness', 7.0,99.0,7.0)
insulin=st.slider('Insulin', 14,850,14)
bmi=st.slider('BMI',18,67,18)
dpf=st.slider('DiabetesPedigreeFunction',0.05,2.50,0.05)
age=st.slider('Age',20,90,20)


#Step3: collect the frontend user input as model input data

data={
'Pregnancies':pregs,
    'Glucose':glucose, 'BloodPressure':bp, 'SkinThickness':skin, 'Insulin':insulin,
       'BMI':bmi, 'DiabetesPedigreeFunction':dpf, 'Age':age
}

input_data=pd.DataFrame([data])


#Step4: get the predictions and print the result

preds=clf.predict(input_data)[0]
if st.button('Predict'):
    if preds==1:
        st.error('Diabetic')
    if preds==0:
        st.success('Non Diabetic')
# Out:
# Overwriting app.py

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')
